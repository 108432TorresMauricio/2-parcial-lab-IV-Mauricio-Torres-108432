-- %% [markdown]
-- # [Club]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Club]    Script Date: 09/11/2020 0:15:19 ******/
CREATE DATABASE [Club]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Club', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL12.MSSQLSERVER\MSSQL\DATA\Club.mdf' , SIZE = 5120KB , MAXSIZE = UNLIMITED, FILEGROWTH = 1024KB )
 LOG ON 
( NAME = N'Club_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL12.MSSQLSERVER\MSSQL\DATA\Club_log.ldf' , SIZE = 1024KB , MAXSIZE = 2048GB , FILEGROWTH = 10%)
GO
ALTER DATABASE [Club] SET COMPATIBILITY_LEVEL = 120
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Club].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Club] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Club] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Club] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Club] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Club] SET ARITHABORT OFF 
GO
ALTER DATABASE [Club] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [Club] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Club] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Club] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Club] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Club] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Club] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Club] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Club] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Club] SET  DISABLE_BROKER 
GO
ALTER DATABASE [Club] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Club] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Club] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Club] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Club] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Club] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Club] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Club] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [Club] SET  MULTI_USER 
GO
ALTER DATABASE [Club] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Club] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Club] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Club] SET TARGET_RECOVERY_TIME = 0 SECONDS 
GO
ALTER DATABASE [Club] SET DELAYED_DURABILITY = DISABLED 
GO

-- %% [markdown]
-- # [dbo].[Actividad]

-- %%
USE [Club]
GO

-- %%
/****** Object:  Table [dbo].[Actividad]    Script Date: 09/11/2020 0:15:19 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Actividad](
	[IdActividad] [int] IDENTITY(1,1) NOT NULL,
	[Descripcion] [varchar](50) NULL,
 CONSTRAINT [PK_Actividad] PRIMARY KEY CLUSTERED 
(
	[IdActividad] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CuotasPagadas]

-- %%
/****** Object:  Table [dbo].[CuotasPagadas]    Script Date: 09/11/2020 0:15:19 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CuotasPagadas](
	[IdCoutasPagadas] [int] IDENTITY(1,1) NOT NULL,
	[Mes] [int] NULL,
	[Año] [int] NULL,
	[IdSocio] [int] NULL,
	[Precio] [float] NULL,
 CONSTRAINT [PK_CuotasPagadas] PRIMARY KEY CLUSTERED 
(
	[IdCoutasPagadas] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Sexo]

-- %%
/****** Object:  Table [dbo].[Sexo]    Script Date: 09/11/2020 0:15:19 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Sexo](
	[IdSexo] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [varchar](50) NULL,
 CONSTRAINT [PK_Sexo] PRIMARY KEY CLUSTERED 
(
	[IdSexo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Socio]

-- %%
/****** Object:  Table [dbo].[Socio]    Script Date: 09/11/2020 0:15:19 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Socio](
	[IdSocio] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [varchar](50) NULL,
	[Apellido] [varchar](50) NULL,
	[Edad] [int] NULL,
	[Telefono] [int] NULL,
	[IdSexo] [int] NULL,
 CONSTRAINT [PK_Socio] PRIMARY KEY CLUSTERED 
(
	[IdSocio] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SocioActividades]

-- %%
/****** Object:  Table [dbo].[SocioActividades]    Script Date: 09/11/2020 0:15:19 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SocioActividades](
	[IdSocio] [int] NULL,
	[IdActividad] [int] NULL,
	[Habilitado] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Actividad]

-- %%
SET IDENTITY_INSERT [dbo].[Actividad] ON 
INSERT [dbo].[Actividad] ([IdActividad], [Descripcion]) VALUES (1, N'Futbol')
INSERT [dbo].[Actividad] ([IdActividad], [Descripcion]) VALUES (2, N'Tenis')
INSERT [dbo].[Actividad] ([IdActividad], [Descripcion]) VALUES (3, N'Natacion')
INSERT [dbo].[Actividad] ([IdActividad], [Descripcion]) VALUES (4, N'Basquet')
INSERT [dbo].[Actividad] ([IdActividad], [Descripcion]) VALUES (5, N'Volley')
INSERT [dbo].[Actividad] ([IdActividad], [Descripcion]) VALUES (6, N'Hockey')
INSERT [dbo].[Actividad] ([IdActividad], [Descripcion]) VALUES (7, N'polo')
INSERT [dbo].[Actividad] ([IdActividad], [Descripcion]) VALUES (10, N'Jambol')
INSERT [dbo].[Actividad] ([IdActividad], [Descripcion]) VALUES (11, N'basquet')
INSERT [dbo].[Actividad] ([IdActividad], [Descripcion]) VALUES (13, N'Atletismo.')
SET IDENTITY_INSERT [dbo].[Actividad] OFF
GO

-- %% [markdown]
-- # [dbo].[CuotasPagadas]

-- %%
SET IDENTITY_INSERT [dbo].[CuotasPagadas] ON 
INSERT [dbo].[CuotasPagadas] ([IdCoutasPagadas], [Mes], [Año], [IdSocio], [Precio]) VALUES (1, 1, 2020, 2, 1500)
INSERT [dbo].[CuotasPagadas] ([IdCoutasPagadas], [Mes], [Año], [IdSocio], [Precio]) VALUES (2, 10, 2020, 14, 1000)
INSERT [dbo].[CuotasPagadas] ([IdCoutasPagadas], [Mes], [Año], [IdSocio], [Precio]) VALUES (4, 9, 2020, 13, 1550)
INSERT [dbo].[CuotasPagadas] ([IdCoutasPagadas], [Mes], [Año], [IdSocio], [Precio]) VALUES (6, 3, 2019, 12, 900)
SET IDENTITY_INSERT [dbo].[CuotasPagadas] OFF
GO

-- %% [markdown]
-- # [dbo].[Sexo]

-- %%
SET IDENTITY_INSERT [dbo].[Sexo] ON 
INSERT [dbo].[Sexo] ([IdSexo], [Nombre]) VALUES (1, N'Masculino')
INSERT [dbo].[Sexo] ([IdSexo], [Nombre]) VALUES (2, N'Femenino')
INSERT [dbo].[Sexo] ([IdSexo], [Nombre]) VALUES (3, N'Otro')
SET IDENTITY_INSERT [dbo].[Sexo] OFF
GO

-- %% [markdown]
-- # [dbo].[Socio]

-- %%
SET IDENTITY_INSERT [dbo].[Socio] ON 
INSERT [dbo].[Socio] ([IdSocio], [Nombre], [Apellido], [Edad], [Telefono], [IdSexo]) VALUES (2, N'Mauricio', N'Torres', 26, 4584544, 1)
INSERT [dbo].[Socio] ([IdSocio], [Nombre], [Apellido], [Edad], [Telefono], [IdSexo]) VALUES (12, N'lucas', N'martinez ', 42, 23123, 1)
INSERT [dbo].[Socio] ([IdSocio], [Nombre], [Apellido], [Edad], [Telefono], [IdSexo]) VALUES (13, N'ramiro', N'gonzalez', 21, 541544, 1)
INSERT [dbo].[Socio] ([IdSocio], [Nombre], [Apellido], [Edad], [Telefono], [IdSexo]) VALUES (14, N'mayra', N'aguirre', 20, 154788, 2)
SET IDENTITY_INSERT [dbo].[Socio] OFF
GO

-- %% [markdown]
-- # [dbo].[SocioActividades]

-- %%
INSERT [dbo].[SocioActividades] ([IdSocio], [IdActividad], [Habilitado]) VALUES (2, 1, 1)
INSERT [dbo].[SocioActividades] ([IdSocio], [IdActividad], [Habilitado]) VALUES (12, 5, 2)
GO

-- %% [markdown]
-- # [FK_CuotasPagadas_Socio]

-- %%
ALTER TABLE [dbo].[CuotasPagadas]  WITH CHECK ADD  CONSTRAINT [FK_CuotasPagadas_Socio] FOREIGN KEY([IdSocio])
REFERENCES [dbo].[Socio] ([IdSocio])
GO
ALTER TABLE [dbo].[CuotasPagadas] CHECK CONSTRAINT [FK_CuotasPagadas_Socio]
GO

-- %% [markdown]
-- # [FK_Socio_Sexo]

-- %%
ALTER TABLE [dbo].[Socio]  WITH CHECK ADD  CONSTRAINT [FK_Socio_Sexo] FOREIGN KEY([IdSexo])
REFERENCES [dbo].[Sexo] ([IdSexo])
GO
ALTER TABLE [dbo].[Socio] CHECK CONSTRAINT [FK_Socio_Sexo]
GO

-- %% [markdown]
-- # [FK_SocioActividades_Actividad]

-- %%
ALTER TABLE [dbo].[SocioActividades]  WITH CHECK ADD  CONSTRAINT [FK_SocioActividades_Actividad] FOREIGN KEY([IdActividad])
REFERENCES [dbo].[Actividad] ([IdActividad])
GO
ALTER TABLE [dbo].[SocioActividades] CHECK CONSTRAINT [FK_SocioActividades_Actividad]
GO

-- %% [markdown]
-- # [FK_SocioActividades_Socio]

-- %%
ALTER TABLE [dbo].[SocioActividades]  WITH CHECK ADD  CONSTRAINT [FK_SocioActividades_Socio] FOREIGN KEY([IdSocio])
REFERENCES [dbo].[Socio] ([IdSocio])
GO
ALTER TABLE [dbo].[SocioActividades] CHECK CONSTRAINT [FK_SocioActividades_Socio]
GO

-- %% [markdown]
-- # [Club]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Club] SET  READ_WRITE 
GO
